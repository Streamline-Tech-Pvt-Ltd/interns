# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('customers.csv')

# %%
df.head()
# Out:
#    customerNumber                customerName contactLastName  \
# 0             103           Atelier graphique         Schmitt
# 1             112          Signal Gift Stores            King
# 2             114  Australian Collectors, Co.        Ferguson
# 3             119           La Rochelle Gifts         Labrune
# 4             121          Baane Mini Imports      Bergulfsen
#
#   contactFirstName         phone                  addressLine1 addressLine2  \
# 0          Carine     40.32.2555                54, rue Royale          NaN
# 1             Jean    7025551838               8489 Strong St.          NaN
# 2            Peter  03 9520 4555             636 St Kilda Road      Level 3
# 3          Janine     40.67.8555  67, rue des Cinquante Otages          NaN
# 4           Jonas     07-98 9555        Erling Skakkes gate 78          NaN
#
#         city     state postalCode    country  salesRepEmployeeNumber  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customerNumber          122 non-null    int64
#  1   customerName            122 non-null    object
#  2   contactLastName         122 non-null    object
#  3   contactFirstName        122 non-null    object
#  4   phone                   122 non-null    object
#  5   addressLine1            122 non-null    object
#  6   addressLine2            22 non-null     object
#  7   city                    122 non-null    object
#  8   state                   49 non-null     object
#  9   postalCode              115 non-null    object
#  10  country                 122 non-null    object
#  11  salesRepEmployeeNumber  100 non-null    float64
#  12  creditLimit             122 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 12.5+ KB

# %%
df.describe()
# Out:
#        customerNumber  salesRepEmployeeNumber    creditLimit
# count      122.000000               100.00000     122.000000
# mean       296.401639              1395.94000   67659.016393
# std        117.077544               165.67193   45043.370751
# min        103.000000              1165.00000       0.000000
# 25%        191.250000              1286.00000   42175.000000
# 50%        298.500000              1370.00000   76700.000000
# 75%        384.250000              1504.00000   95075.000000
# max        496.000000              1702.00000  227600.000000

# %%
df.isnull().sum()
# Out:
# customerNumber              0
# customerName                0
# contactLastName             0
# contactFirstName            0
# phone                       0
# addressLine1                0
# addressLine2              100
# city                        0
# state                      73
# postalCode                  7
# country                     0
# salesRepEmployeeNumber     22
# creditLimit                 0
# dtype: int64

# %%
df.drop(columns=['addressLine2'], inplace=True)

# %%
df.head(1)
# Out:
#    customerNumber       customerName contactLastName contactFirstName  \
# 0             103  Atelier graphique         Schmitt          Carine
#
#         phone    addressLine1    city state postalCode country  \
# 0  40.32.2555  54, rue Royale  Nantes   NaN      44000  France
#
#    salesRepEmployeeNumber  creditLimit
# 0                  1370.0      21000.0

# %%
df['salesRepEmployeeNumber'] = df['salesRepEmployeeNumber'].fillna('Not Assigned')

# %%
df = df[df['postalCode'].notna()]

# %%
df['state'] = df['state'].fillna('Not Assigned')

# %%
df.isnull().sum()
# Out:
# customerNumber            0
# customerName              0
# contactLastName           0
# contactFirstName          0
# phone                     0
# addressLine1              0
# city                      0
# state                     0
# postalCode                0
# country                   0
# salesRepEmployeeNumber    0
# creditLimit               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['phone'].duplicated().sum()
# Out:
# 1

# %%
df[df['phone'].duplicated(keep=False)]['phone']
# Out:
# 58    6175558555
# 88    6175558555
# Name: phone, dtype: object

# %%
df.loc[[58,88]]
# Out:
#     customerNumber                customerName contactLastName  \
# 58             286        Marta's Replicas Co.       Hernandez
# 88             379  Collectables For Less Inc.          Nelson
#
#    contactFirstName       phone         addressLine1        city state  \
# 58            Marta  6175558555  39323 Spinnaker Dr.   Cambridge    MA
# 88            Allen  6175558555     7825 Douglas Av.  Brickhaven    MA
#
#    postalCode country salesRepEmployeeNumber  creditLimit
# 58      51247     USA                 1216.0     123700.0
# 88      58339     USA                 1188.0      70700.0

# %%
df = df.drop(index=58)

# %%
df.shape
# Out:
# (114, 12)

# %%
df.dtypes
# Out:
# customerNumber              int64
# customerName               object
# contactLastName            object
# contactFirstName           object
# phone                      object
# addressLine1               object
# city                       object
# state                      object
# postalCode                 object
# country                    object
# salesRepEmployeeNumber     object
# creditLimit               float64
# dtype: object

# %%
df = df.astype({
    'customerName'           : 'string',               
    'contactLastName'        : 'string',              
    'contactFirstName'       : 'string',   
    'phone'                  : 'string',    
    'addressLine1'           : 'string',   
    'city'                   : 'string',    
    'state'                  : 'string',      
    'postalCode'             : 'string',   
    'country'                : 'string',     
    'salesRepEmployeeNumber' : 'string'
   
})

# %%
#df['phone'] = df['phone'].astype(float)

# %%
df[pd.to_numeric(df['phone'], errors='coerce').isna()].sample()
# Out:
#     customerNumber       customerName contactLastName contactFirstName  \
# 21             169  Porto Imports Co.       de Castro          Isabel
#
#            phone            addressLine1    city         state postalCode  \
# 21  (1) 356-5555  Estrada da saúde n. 58  Lisboa  Not Assigned       1756
#
#      country salesRepEmployeeNumber  creditLimit
# 21  Portugal           Not Assigned          0.0

# %%
df[pd.to_numeric(df['salesRepEmployeeNumber'], errors='coerce').isna()].sample()
# Out:
#      customerNumber         customerName contactLastName contactFirstName  \
# 113             477  Mit Vergnügen & Co.            Moos           Hanna
#
#           phone    addressLine1      city         state postalCode  country  \
# 113  0621-08555  Forsterstr. 57  Mannheim  Not Assigned      68306  Germany
#
#     salesRepEmployeeNumber  creditLimit
# 113           Not Assigned          0.0

# %%
df.dtypes
# Out:
# customerNumber                     int64
# customerName              string[python]
# contactLastName           string[python]
# contactFirstName          string[python]
# phone                     string[python]
# addressLine1              string[python]
# city                      string[python]
# state                     string[python]
# postalCode                string[python]
# country                   string[python]
# salesRepEmployeeNumber    string[python]
# creditLimit                      float64
# dtype: object

# %%
df = df.rename(columns={
    'customerName': 'companyName',
    'addressLine1': 'address'
})

# %%
df.columns
# Out:
# Index(['customerNumber', 'companyName', 'contactLastName', 'contactFirstName',
#        'phone', 'address', 'city', 'state', 'postalCode', 'country',
#        'salesRepEmployeeNumber', 'creditLimit'],
#       dtype='object')

# %%
#df.to_csv("cleaned_data.csv", index=False)
